# %%
using Plots, CSV, DataFrames
df = DataFrame(CSV.read("Freq_all.csv"));

# %%
sort!(df, (:f1))
onee = scatter(df.c[1:50],-df.r[1:50], title = "Method 1", label="", grid = true, aspect_ratio=:equal)

# %%
sort!(df, (:f2))
twoo = scatter(df.c[1:50],-df.r[1:50], title = "Method 2", label="", grid = true, aspect_ratio=:equal)

# %%
sort!(df, (:f3))
three = scatter(df.c[1:50],-df.r[1:50], title = "Method 2+", label="", grid = true, aspect_ratio=:equal)

# %%
sort!(df, (:f4))
four = scatter(df.c[1:50],-df.r[1:50], title = "Method 2-", label="", grid = true, aspect_ratio=:equal)

# %%
sort!(df, (:fall))
all = scatter(df.c[1:50],-df.r[1:50], title = "All Methods", label="", grid = true, aspect_ratio=:equal)

# %%
p = plot(onee, twoo, three, four, layout = 4)
