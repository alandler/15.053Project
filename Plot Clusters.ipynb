# %%
using Plots, CSV, DataFrames
df = DataFrame(CSV.read("Freq_all.csv"));

# %%
sort!(df, (:f1))
one50 = scatter(df.c[1:50],-df.r[1:50], title = "Model 1 - 50", label="", grid = true, aspect_ratio=:equal,xlim = [0,50], ylim = [-50,0])
one25 = scatter(df.c[1:25],-df.r[1:50], title = "Model 1 - 25", label="", grid = true, aspect_ratio=:equal,xlim = [0,50], ylim = [-50,0])
one20 = scatter(df.c[1:20],-df.r[1:50], title = "Model 1 - 20", label="", grid = true, aspect_ratio=:equal,xlim = [0,50], ylim = [-50,0])
one10 = scatter(df.c[1:10],-df.r[1:50], title = "Model 1 - 10", label="", grid = true, aspect_ratio=:equal,xlim = [0,50], ylim = [-50,0])

# %%
sort!(df, (:f1))
plot(one50, one25, one20, one10, layout = 4)

# %%
sort!(df, (:f2))
twoo = scatter(df.c[1:50],-df.r[1:50], title = "Model 2", label="", grid = true, aspect_ratio=:equal,xlim = [0,50], ylim = [-50,0])

# %%
sort!(df, (:f3))
three = scatter(df.c[1:50],-df.r[1:50], title = "Model 2+", label="", grid = true, aspect_ratio=:equal,xlim = [0,50], ylim = [-50,0])

# %%
sort!(df, (:f4))
four = scatter(df.c[1:50],-df.r[1:50], title = "Model 2-", label="", grid = true, aspect_ratio=:equal,xlim = [0,50], ylim = [-50,0])

# %%
sort!(df, (:fall))
all = scatter(df.c[1:50],-df.r[1:50], title = "All Models", label="", grid = true, aspect_ratio=:equal,xlim = [0,50], ylim = [-50,0])

# %%
p = plot(one50, twoo, three, four, layout = 4)
