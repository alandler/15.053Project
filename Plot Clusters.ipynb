# %%
using Plots, CSV, DataFrames
df = DataFrame(CSV.read("Compiled_ACTUAL.csv"));

# %%
sort!(df, (:f1))
scatter(df.c[1:50],df.r[1:50], label="cluster", grid = true, lims = [0,50], aspect_ratio=:equal)

# %%
sort!(df, (:f2))
scatter(df.c[1:50],df.r[1:50], label="cluster", grid = true, lims = [0,50], aspect_ratio=:equal)

# %%
sort!(df, (:f3))
scatter(df.c[1:50],df.r[1:50], label="cluster", grid = true, lims = [0,50], aspect_ratio=:equal)

# %%
sort!(df, (:f4))
scatter(df.c[1:50],df.r[1:50], label="cluster", grid = true, lims = [0,50], aspect_ratio=:equal)

# %%
sort!(df, (:fall))
scatter(df.c[1:50],df.r[1:50], label="cluster", grid = true, lims = [0,50], aspect_ratio=:equal)
